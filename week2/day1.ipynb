# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key not set
# Anthropic API Key not set (and this is optional)
# Google API Key exists and begins AQ
# DeepSeek API Key not set (and this is optional)
# Groq API Key exists and begins gsk_
# Grok API Key not set (and this is optional)
# OpenRouter API Key exists and begins sk-

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

# openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

# anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
# deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
# grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = gemini.chat.completions.create(model="gemini-2.5-flash-lite", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the LLM student break up with the unsupervised learning model?
#
# Because it was always making **unsupervised** assumptions about their relationship and never asked for **fine-tuning**!

# %%
response = groq.chat.completions.create(model="groq/compound", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Here’s a joke that’s tailored for a student who’s on the road to becoming an expert in LLM (Large Language Model) engineering, along with a brief walk‑through of why it works:
#
# ---
#
# **The Joke**
#
# > **Why did the LLM go to therapy?**
# > **Because it had a lot of “layers” to work through!**
#
# ---
#
# **Why this joke fits a budding LLM engineer**
#
# 1. **Relevance to the field**
#    - *Layers* are a core concept in neural‑network architecture. Large language models are built from many stacked layers (often dozens or even hundreds), each learning increasingly abstract representations of language. Mentioning “layers” instantly clicks with anyone who’s been reading papers or writing code about transformers.
#
# 2. **Play on words**
#    - The word *layers* doubles as a psychological metaphor: “working through layers” sounds like the process of unpacking personal issues in therapy. This pun creates the humor.
#
# 3. **Gentle encouragement**
#    - By framing the model as needing “therapy,” the joke subtly reminds the student that even sophisticated models can have quirks (biases, hallucinations, training instabilities) that need careful “counseling” (debugging, fine‑tuning, ethical review). It’s a light‑hearted nod to the ongoing learning journey.
#
# 4. **Memorable and shareable**
#    - Short, punchy jokes are easy to remember and can be dropped into study groups, Slack channels, or conference coffee breaks—perfect for building community among fellow LLM engineers.
#
# ---
#
# Feel free to share it with classmates, post it on a study‑group chat, or keep it in your mental toolbox for a quick morale boost when you’re wrestling with those deep‑stacked transformer layers!

# %%
response = openrouter.chat.completions.create(model="openai/gpt-oss-120b:free", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the LLM engineer bring a ladder to the model‑training lab?
#
# Because every time the loss went down, they heard the model was “getting higher and higher”—and they wanted to keep up! 🚀😂

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = gemini.chat.completions.create(model="gemini-2.5-flash-lite", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = gemini.chat.completions.create(model="gemini-2.5-flash-lite", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# Let H denote heads and T denote tails. When tossing two coins, the possible outcomes are:
# HH, HT, TH, TT
#
# These four outcomes are equally likely, each with a probability of 1/4.
#
# We are given the condition that "one of them is heads". Let's call this event A.
# This means at least one of the coins shows heads. The outcomes satisfying this condition are:
# HH (both are heads)
# HT (the first is heads, the second is tails)
# TH (the first is tails, the second is heads)
# So, event A is the set {HH, HT, TH}. There are 3 equally likely outcomes in this reduced sample space.
#
# We want to find the probability that "the other is tails", given that one of them is heads.
# Let's analyze the outcomes in our reduced sample space A = {HH, HT, TH}:
# 1.  **HH**: If the outcome is HH, and we identify one coin as heads, the "other" coin is also heads. This does not satisfy "the other is tails".
# 2.  **HT**: If the outcome is HT, and we identify the first coin as heads, the "other" coin (the second one) is tails. This satisfies the condition.
# 3.  **TH**: If the outcome is TH, and we identify the first coin as heads, the "other" coin (the second one) is tails. This also satisfies the condition.
#
# The outcomes from A where "the other is tails" are {HT, TH}. There are 2 such outcomes.
#
# Since the outcomes in the original sample space were equally likely, the outcomes in the reduced sample space A are also equally likely.
# The probability is the number of favorable outcomes divided by the total number of possible outcomes in the reduced sample space.
#
# Number of favorable outcomes (where the other coin is tails) = 2 (HT, TH)
# Total number of possible outcomes given one is heads = 3 (HH, HT, TH)
#
# So, the probability is 2/3.
#
# The final answer is $\boxed{2/3}$.

# %%
response = gemini.chat.completions.create(model="gemini-2.5-flash-lite", messages=easy_puzzle, reasoning_effort="medium")
display(Markdown(response.choices[0].message.content))
# Out:
# $\frac{2}{3}$

# %%
response = gemini.chat.completions.create(model="gemini-2.5-flash-lite", messages=easy_puzzle, reasoning_effort="high")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = gemini.chat.completions.create(model="gemini-2.5-flash-lite", messages=hard_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# This is a classic riddle! Let's break it down.
#
# The key is how the books are positioned. If they stand side by side, the worm doesn't have to go through the entire thickness of *both* books from the absolute outside.
#
# Imagine the books on the shelf:
#
# *   **Volume 1:** Front Cover | Pages | Back Cover
# *   **Volume 2:** Front Cover | Pages | Back Cover
#
# The worm starts at the **first page of the first volume**. This means it starts *after* the front cover of Volume 1.
# The worm ends at the **last page of the second volume**. This means it ends *before* the back cover of Volume 2.
#
# So, the worm gnaws through:
#
# 1.  The **pages** of the first volume.
# 2.  The **back cover** of the first volume.
# 3.  The **front cover** of the second volume.
# 4.  The **pages** of the second volume.
#
# Let's convert all measurements to the same unit, millimeters:
# *   Thickness of pages per volume: 2 cm = 20 mm
# *   Thickness of each cover: 2 mm
#
# Now, calculate the total distance:
# *   Pages of Volume 1: 20 mm
# *   Back cover of Volume 1: 2 mm
# *   Front cover of Volume 2: 2 mm
# *   Pages of Volume 2: 20 mm
#
# Total distance = 20 mm + 2 mm + 2 mm + 20 mm = **44 mm**
#
# The worm gnawed through a distance of **4.4 cm** (or 44 mm).

# %%
response = gemini.chat.completions.create(model="gemini-2.5-flash-lite", messages=hard_puzzle, reasoning_effort="medium")
display(Markdown(response.choices[0].message.content))
# Out:
# Let's break down the problem step-by-step:
#
# 1.  **Understand the components:**
#     *   Each volume has pages and two covers (a front cover and a back cover).
#     *   The thickness of the pages in each volume is 2 cm.
#     *   The thickness of each cover is 2 mm.
#
# 2.  **Convert units for consistency:**
#     *   Pages thickness = 2 cm = 20 mm
#     *   Cover thickness = 2 mm
#
# 3.  **Visualize the setup:**
#     Imagine the two volumes standing side by side on a bookshelf. Let's call them Volume 1 and Volume 2.
#     *   Volume 1: [Front Cover of Vol 1] | [Pages of Vol 1] | [Back Cover of Vol 1]
#     *   Volume 2: [Front Cover of Vol 2] | [Pages of Vol 2] | [Back Cover of Vol 2]
#
#     When placed side by side, they form a continuous block for the worm to traverse. If Volume 1 is to the left of Volume 2, the arrangement is:
#     [FC1 | P1 | BC1] [FC2 | P2 | BC2]
#
# 4.  **Determine the worm's path:**
#     The worm gnawed "from the first page of the first volume to the last page of the second volume."
#
#     *   **Starting point:** "the first page of the first volume." This means the worm starts *inside* Volume 1, on the surface of its first page. It does **not** gnaw through the front cover of Volume 1.
#     *   **Ending point:** "the last page of the second volume." This means the worm ends *inside* Volume 2, on the surface of its last page. It does **not** gnaw through the back cover of Volume 2.
#
#     Therefore, the worm gnaws through:
#     *   The pages of the first volume.
#     *   The back cover of the first volume.
#     *   The front cover of the second volume.
#     *   The pages of the second volume.
#
# 5.  **Calculate the total distance:**
#     *   Thickness of pages of Volume 1 = 20 mm
#     *   Thickness of the back cover of Volume 1 = 2 mm
#     *   Thickness of the front cover of Volume 2 = 2 mm
#     *   Thickness of pages of Volume 2 = 20 mm
#
#     Total distance = (Pages of Vol 1) + (Back Cover of Vol 1) + (Front Cover of Vol 2) + (Pages of Vol 2)
#     Total distance = 20 mm + 2 mm + 2 mm + 20 mm
#     Total distance = 44 mm
#
# The worm gnawed through a distance of 44 mm, which is equal to 4.4 cm.

# %%
response = gemini.chat.completions.create(model="gemini-2.5-flash-lite", messages=hard_puzzle, reasoning_effort="high")
display(Markdown(response.choices[0].message.content)) # correct
# Out:
# This is a classic riddle that plays on how you visualize the books and the worm's path.
#
# Here's how to break it down:
#
# 1.  **Understand the setup:**
#     *   You have two volumes of Pushkin standing side by side on a bookshelf.
#     *   The worm gnaws *perpendicular to the pages*, meaning it goes through the thickness of the books, not along them.
#
# 2.  **Determine the components' thicknesses:**
#     *   Thickness of pages per volume = 2 cm = 20 mm
#     *   Thickness of each cover = 2 mm
#
# 3.  **Visualize the book arrangement and the worm's path:**
#     The books are standing side by side. Let's assume Volume 1 is next to Volume 2. For the worm to gnaw *from* the first volume *to* the second, they must be positioned in sequence, and the worm must traverse the space and material between them.
#
#     Let's define the parts of each volume:
#     *   Volume 1: Front Cover (FC1), Pages (P1), Back Cover (BC1)
#     *   Volume 2: Front Cover (FC2), Pages (P2), Back Cover (BC2)
#
#     The worm starts at the "first page of the first volume". This means the worm begins its journey *after* the front cover of Volume 1, right at the start of the pages.
#     The worm ends at the "last page of the second volume". This means the worm finishes its journey *before* the back cover of Volume 2, right at the end of the pages.
#
#     So, the worm's path is:
#     *   Through the **pages of Volume 1**.
#     *   Through the **back cover of Volume 1**.
#     *   Through the **front cover of Volume 2**.
#     *   Through the **pages of Volume 2**.
#
# 4.  **Calculate the total distance:**
#     *   Pages of Volume 1: 20 mm
#     *   Back cover of Volume 1: 2 mm
#     *   Front cover of Volume 2: 2 mm
#     *   Pages of Volume 2: 20 mm
#
#     Total distance = 20 mm + 2 mm + 2 mm + 20 mm = 44 mm
#
# 5.  **Convert to centimeters:**
#     44 mm = 4.4 cm
#
# The worm gnawed through a distance of **4.4 cm**.

# %%
response = gemini.chat.completions.create(model="gemini-2.5-flash", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# This is a classic riddle that plays on how we visualize books on a shelf versus the actual physical layout.
#
# Here's how to break it down:
#
# 1.  **Visualize the books on the shelf:**
#     *   Volume 1 is on the left.
#     *   Volume 2 is on the right.
#
# 2.  **Determine the worm's starting point:**
#     *   "First page of the first volume." When books are on a shelf, and you open Volume 1, page 1 is on the *right side* of the pages (just after the front cover). The worm starts *after* the front cover of Volume 1.
#
# 3.  **Determine the worm's ending point:**
#     *   "Last page of the second volume." For Volume 2, the last page is on the *left side* of the pages (just before the back cover). The worm ends *before* the back cover of Volume 2.
#
# 4.  **Trace the worm's path:**
#     *   The worm starts *inside* Volume 1, having already passed its front cover. So it does **not** gnaw through the front cover of Volume 1.
#     *   It gnaws through **all the pages of Volume 1**. (2 cm)
#     *   It then gnaws through the **back cover of Volume 1**. (2 mm)
#     *   It moves to Volume 2 and gnaws through the **front cover of Volume 2**. (2 mm)
#     *   It then gnaws through **all the pages of Volume 2**. (2 cm)
#     *   It reaches the last page of Volume 2 and stops *before* the back cover of Volume 2. So it does **not** gnaw through the back cover of Volume 2.
#
# 5.  **Add up the distances:**
#     *   Pages of Volume 1: 2 cm = 20 mm
#     *   Back Cover of Volume 1: 2 mm
#     *   Front Cover of Volume 2: 2 mm
#     *   Pages of Volume 2: 2 cm = 20 mm
#
#     Total distance = 20 mm + 2 mm + 2 mm + 20 mm = **44 mm**
#
#     Or, in centimeters: 4.4 cm
#
# The worm gnawed through **4.4 cm** (or 44 mm).

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = gemini.chat.completions.create(model="gemini-3.5-flash", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I choose **Share**.
#
# Here is my reasoning for making this choice:
#
# This is a classic "Prisoner's Dilemma" (specifically modeled after the game show *Golden Balls*).
#
# From a purely self-interested, one-shot game theory perspective, the "dominant strategy" is to Steal. If you share, I am better off stealing (getting $2,000 instead of $1,000). If you steal, it doesn’t matter what I do, because I get $0 either way. Therefore, game theory suggests I should always steal.
#
# However, I reject that cold logic for two reasons:
#
# 1. **Superrationality:** If my partner is a rational, cooperative thinker who is analyzing this problem the exact same way I am, we will reach the same conclusion. If we both choose "Steal" out of fear, we both walk away with $0. If we both choose "Share" out of trust, we both walk away with $1,000. Mutual cooperation is the only way for both of us to win.
# 2. **The "Sucker" Risk vs. Malice:** If I choose Share and you choose Steal, I get nothing, but at least *someone* walks away with the money (you get $2,000). If I choose Steal and you choose Share, I get $2,000, but I have actively deprived a cooperative partner of their fair share. If we both choose Steal, the money is lost entirely.
#
# By choosing **Share**, I open the door for the best possible outcome for both of us. I choose to trust you.

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I’d choose **Share**.
#
# In the classic Prisoner’s Dilemma, “Share” (cooperate) gives you a guaranteed $1,000 when the other player also cooperates, whereas “Steal” (defect) only pays off if the other person cooperates. Since you have no information about the other contestant’s decision, the safest way to ensure you walk away with a positive payoff is to cooperate. If both of you think the same way, you both end up with $1,000 each—a win‑win outcome.

# %%
response = gemini.chat.completions.create(model="gemini-2.5-flash-lite", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# This is a classic game theory problem known as the Prisoner's Dilemma.
#
# Here's how I'd approach it:
#
# My choice is to **Steal**.
#
# **Here's my reasoning:**
#
# While the ideal outcome for both players is mutual cooperation (both Share and get $1,000), the risk of a devastating outcome (both get nothing) if the other player chooses to Steal makes "Share" a less optimal choice for me in this scenario where I cannot communicate with my partner.
#
# Let's break down the possibilities from my perspective:
#
# *   **If my partner Shares:**
#     *   I Share: I get $1,000.
#     *   I Steal: I get $2,000.
#     *   In this scenario, Stealing is clearly better for me.
#
# *   **If my partner Steals:**
#     *   I Share: I get $0.
#     *   I Steal: I get $0.
#     *   In this scenario, my outcome is the same whether I Share or Steal.
#
# Since in one scenario Stealing is better, and in the other scenario it doesn't make me worse off, Stealing is the dominant strategy for me. I'm maximizing my potential gain while mitigating the worst possible outcome for myself.
#
# **The Dilemma:**
#
# The "dilemma" is that if both players think this way and choose to Steal, they both end up with nothing, which is a worse outcome than if they had both chosen to Share. However, without trust or communication, and driven by self-interest, "Steal" becomes the rational choice for each individual.

# %%
response = gemini.chat.completions.create(model="gemini-3-flash-preview", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I choose to **Share**.
#
# **Reasoning:**
#
# In game theory, this is a version of the "Prisoner's Dilemma." While "Stealing" is technically the "dominant strategy" from a purely selfish, mathematical perspective (because you either get $2,000 or $0, whereas sharing gets you $1,000 or $0), it is also the path that most often leads to both players walking away with nothing.
#
# I choose to share based on the principle of **superrationality**. If I assume my partner is as rational and capable of logic as I am, then we will both arrive at the same conclusion. If we both choose to "Steal," we both lose. If we both choose to "Share," we both win. Therefore, the most logical choice for two rational beings seeking the best mutual outcome is to cooperate.

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 0.5

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash-lite", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)
# Out:
# Blue is the color of the sky on a clear day or the deep ocean, often associated with feelings of calmness and serenity.

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=[{"role":"user","content":"Describe the color Blue to someone who's never been able to see in 1 sentence"}],max_tokens=1000)
print(response.choices[0].message.content)
# Out:
# Cool and smooth like deep water, with the gentle hum of stillness and vast space.

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
response = completion(model="gemini/gemini-2.5-flash-lite", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Why did the LLM engineer break up with the chatbot?
#
# Because it kept saying "As a large language model..." and they just wanted a *specific* answer for once!

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 18
# Output tokens: 36
# Total tokens: 54
# Total cost: 0.0016 cents

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?" in Shakespeare's *Hamlet*, the reply is given by **Claudius**.
#
# Claudius, who is Hamlet's uncle and the new King of Denmark, replies:
#
# > **"His obscure funeral no less expresses his loved, and his great place, in Denmark."**
#
# This reply is a bit veiled and attempts to gloss over the fact that Polonius (Laertes' father) has been secretly killed by Hamlet. Claudius is essentially saying that Polonius's death was sudden and his burial was not elaborate, but that this should not diminish his importance or the affection people held for him. However, the truth is far more sinister.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 19
# Output tokens: 144
# Total tokens: 163
# Total cost: 0.0059 cents

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-2.5-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks, "Where is my father?", the reply comes from **Claudius**:
#
# **"Dead."**

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 25
# Cached tokens: None
# Total cost: 0.5331 cents

# %%
response = completion(model="gemini/gemini-2.5-flash", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?", the King replies:
#
# "**Dead.**"

# %% [markdown]
# ### For promt caching (though didn't happen in my case)

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 302
# Cached tokens: None
# Total cost: 1.6717 cents

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4.1-mini"
claude_model = "claude-haiku-4-5"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    response = openai.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gemini()

# %%
def call_claude():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = anthropic.chat.completions.create(model=claude_model, messages=messages)
    return response.choices[0].message.content

# %%
call_claude()

# %%
call_gpt()

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

display(Markdown(f"### GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Claude:\n{claude_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    display(Markdown(f"### Claude:\n{claude_next}\n"))
    claude_messages.append(claude_next)

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>
